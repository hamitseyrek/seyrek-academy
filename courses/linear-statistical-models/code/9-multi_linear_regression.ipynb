# %% [markdown]
# Çoklu Doğrusal Regresyon ile Tahmin

# %%
import pandas as pd

df = pd.read_csv('../resources/factory_quality_regression.csv')
print(df.head(2))
# Out:
#    machine_id line  runtime_hours  sensor_alert_score  uptime_rate  \
# 0           1    A              6                58.0         72.0
# 1           2    A              8                65.0         80.0
#
#    maintenance_hours  cycle_count  quality_score
# 0                6.4       5200.0             62
# 1                6.8       6100.0             68

# %%
numeric_colums = [
    "sensor_alert_score",
    "quality_score",
    'uptime_rate',
    'maintenance_hours',
    'cycle_count',
    'runtime_hours'
]

for col in numeric_colums:
    df[col] = df[col].fillna(df[col].median())

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

features = ['runtime_hours', 'uptime_rate', 'maintenance_hours']
X = df[features]
y = df['quality_score']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred)


print('b0:', model.intercept_)
print('b1:', model.coef_[0])
print('b2:', model.coef_[1])
print('b3:', model.coef_[2])

print('R2:', r2_score(y, y_pred))
print('RMSE:', float(mean_squared_error(y, y_pred)))
# Out:
# [61.44643579 69.18005497 54.05454446 76.91367415 82.91469422 65.91725908
#  73.04686456 57.92135405 80.43875589 70.04635452 50.18773487 61.78816364
#  65.05095953 73.61115726 76.6116673  54.92084401 69.48206182 83.74127278
#  58.48564675 79.61217734 61.74844264 68.61576227 46.32092528 73.91316411
#  87.00406867 65.61525223 76.91367415 54.61883716 80.47847689 70.34836137
#  64.74895268 73.91316411 61.44643579 89.70257185 41.58781613 92.70308189
#  69.48206182 66.82327963 73.42831341 77.215681  ]
# b0: 10.11038517255205
# b1: 2.1342104861371327
# b2: 0.302006850595848
# b3: 2.622858508544964
# R2: 0.9916283374071485
# RMSE: 1.1016898680627683

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

features = ['runtime_hours', 'uptime_rate', 'maintenance_hours']
X = df[features]
y = df['quality_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print('R2:', r2_score(y_test, y_pred))
print('RMSE:', float(mean_squared_error(y_test, y_pred)))
# Out:
# R2: 0.9817594045930927
# RMSE: 1.4119994236166313
