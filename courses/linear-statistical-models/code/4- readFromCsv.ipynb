# %%
import pandas as pd

df = pd.read_csv("student.csv")

print(df.shape)
print(df.columns)
df.tail()
# Out:
# (40, 8)
# Index(['student_id', 'section', 'weekly_study_hours', 'quiz_score',
#        'attendance_rate', 'sleep_hours', 'steps', 'project_score'],
#       dtype='str')
#     student_id section  weekly_study_hours  quiz_score  attendance_rate  \
# 35          36       C                  15        91.0             98.0
# 36          37       A                   8         NaN             81.0
# 37          38       B                   7        64.0              NaN
# 38          39       C                   9        72.0             87.0
# 39          40       A                  10        76.0             89.0
#
#     sleep_hours   steps  project_score
# 35          8.0  9600.0             93
# 36          6.8  6300.0             69
# 37          6.6  5800.0             66
# 38          NaN  7600.0             75
# 39          7.2     NaN             79

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          40 non-null     int64
#  1   section             40 non-null     str
#  2   weekly_study_hours  40 non-null     int64
#  3   quiz_score          39 non-null     float64
#  4   attendance_rate     39 non-null     float64
#  5   sleep_hours         39 non-null     float64
#  6   steps               39 non-null     float64
#  7   project_score       40 non-null     int64
# dtypes: float64(4), int64(3), str(1)
# memory usage: 2.6 KB
# None

# %%
df['quiz_score'] = df['quiz_score'].fillna(df['quiz_score'].mean())
print(df.isnull().sum())
# Out:
# student_id            0
# section               0
# weekly_study_hours    0
# quiz_score            0
# attendance_rate       1
# sleep_hours           1
# steps                 1
# project_score         0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# student_id            0
# section               0
# weekly_study_hours    0
# quiz_score            1
# attendance_rate       1
# sleep_hours           1
# steps                 1
# project_score         0
# dtype: int64
