# %% [markdown]
# NumPyNumPy:
# 	•	Python’da numerical computing (sayısal hesaplama) için kullanılan temel kütüphanedir.
# 	•	Özellikle:
# 	•	vektör/matris işlemleri
# 	•	istatistiksel hesaplamalar
# 	•	lineer cebir
# 	•	performanslı veri işleme
#
#   Python’un standart listelerine göre:
# 	•	daha hızlı
# 	•	daha optimize
# 	•	matematiksel işlemler için daha uygun

# %%
scores = [60,70,80,90]

print(sum(scores)/len(scores))
# Out:
# 75.0

# %%
import numpy as np

scores_array = np.array(scores)
scores_array.mean(), scores_array.std()

scores_array + 10
# Out:
# array([ 70,  80,  90, 100])
